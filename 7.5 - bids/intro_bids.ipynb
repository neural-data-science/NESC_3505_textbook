# %% [markdown]
# # The Brain Imaging Dat Structure (BIDS) Specification
#
# ## Introduction
# The Brain Imaging Data Structure (BIDS) is a standard for organizing and describing neuroimaging and behavioral data. It aims to facilitate data sharing, reproducibility, and collaboration in the neuroscience community by providing a consistent framework for structuring datasets.

# %%
import bids
from os.path import join
from bids import BIDSLayout
import os
import subprocess

# %%
# Create data directory if it doesn't exist
os.makedirs('./data', exist_ok=True)
bids_root = './data/eeg_face13'
# Out:
# Downloading eeg_face13 dataset...
# Cloning into './data/bids-examples'...
# Dataset downloaded successfully!

# %%
# Clone the BIDS examples repository with sparse checkout to get only eeg_face13
if not os.path.exists(bids_root):
    print("Downloading eeg_face13 dataset...")
    # Use git sparse-checkout to only get the specific example
    subprocess.run([
        'git', 'clone', '--depth', '1', '--filter=blob:none', '--sparse',
        'https://github.com/bids-standard/bids-examples.git',
        './data/bids-examples'
    ], check=True)
    
    os.chdir('./data/bids-examples')
    subprocess.run(['git', 'sparse-checkout', 'set', 'eeg_face13'], check=True)
    os.chdir('../..')
    
    # Move the dataset to the desired location
    subprocess.run(['mv', './data/bids-examples/eeg_face13', './data/'], check=True)
    subprocess.run(['rm', '-rf', './data/bids-examples'], check=True)
    print("Dataset downloaded successfully!")
else:
    print("Dataset already exists at " + bids_root)")

# %%
# Load the BIDS dataset
layout = bids.BIDSLayout(bids_root)

# %%
layout.get_subjects()
# Out:
# ['001', '002', '003', '004', '005', '006', '007', '008', '009', '010']

# %%
layout.get_sessions()
# Out:
# []

# %%
layout.get_tasks()
# Out:
# ['faceFO']

# %%
all_files = layout.get()
print("There are {} files in the layout.".format(len(all_files)))
print("\nThe first 10 files are:")
all_files[:10]
# Out:
# There are 63 files in the layout.
#
# The first 10 files are:
# [<BIDSJSONFile filename='/Users/aaron/3505/NESC_3505_textbook/7.5 - bids/data/eeg_face13/dataset_description.json'>,
#  <BIDSDataFile filename='/Users/aaron/3505/NESC_3505_textbook/7.5 - bids/data/eeg_face13/participants.tsv'>,
#  <BIDSFile filename='/Users/aaron/3505/NESC_3505_textbook/7.5 - bids/data/eeg_face13/README'>,
#  <BIDSJSONFile filename='/Users/aaron/3505/NESC_3505_textbook/7.5 - bids/data/eeg_face13/sub-001/eeg/sub-001_coordsystem.json'>,
#  <BIDSDataFile filename='/Users/aaron/3505/NESC_3505_textbook/7.5 - bids/data/eeg_face13/sub-001/eeg/sub-001_electrodes.tsv'>,
#  <BIDSDataFile filename='/Users/aaron/3505/NESC_3505_textbook/7.5 - bids/data/eeg_face13/sub-001/eeg/sub-001_task-faceFO_channels.tsv'>,
#  <BIDSFile filename='/Users/aaron/3505/NESC_3505_textbook/7.5 - bids/data/eeg_face13/sub-001/eeg/sub-001_task-faceFO_eeg.edf'>,
#  <BIDSJSONFile filename='/Users/aaron/3505/NESC_3505_textbook/7.5 - bids/data/eeg_face13/sub-001/eeg/sub-001_task-faceFO_eeg.json'>,
#  <BIDSDataFile filename='/Users/aaron/3505/NESC_3505_textbook/7.5 - bids/data/eeg_face13/sub-001/eeg/sub-001_task-faceFO_events.tsv'>,
#  <BIDSJSONFile filename='/Users/aaron/3505/NESC_3505_textbook/7.5 - bids/data/eeg_face13/sub-002/eeg/sub-002_coordsystem.json'>]

# %%
def print_tree_dirs_only(directory, prefix="", is_last=True, max_depth=None, current_depth=0, show_files_at_root=True):
    """
    Print an ASCII tree structure showing only directories in nested folders,
    but show files at the root level
    """
    if max_depth is not None and current_depth >= max_depth:
        return
    
    # Get the directory name
    dir_name = os.path.basename(directory)
    
    # Print current directory
    if current_depth == 0:
        print(dir_name + "/")
    
    # Get all items in directory
    try:
        items = sorted(os.listdir(directory))
    except PermissionError:
        return
    
    # Filter out hidden files and .git directory
    items = [item for item in items if not item.startswith('.')]
    
    # Separate directories and files
    dirs = [item for item in items if os.path.isdir(os.path.join(directory, item))]
    files = [item for item in items if os.path.isfile(os.path.join(directory, item))]
    
    # Only show files at root level (depth 0)
    if current_depth == 0 and show_files_at_root:
        all_items = dirs + files
    else:
        all_items = dirs
    
    for i, item in enumerate(all_items):
        is_last_item = i == len(all_items) - 1
        item_path = os.path.join(directory, item)
        
        # Determine the prefix for this item
        if is_last_item:
            current_prefix = prefix + "└── "
            extension = prefix + "    "
        else:
            current_prefix = prefix + "├── "
            extension = prefix + "│   "
        
        # Print the item
        if os.path.isdir(item_path):
            print(current_prefix + item + "/")
            # Recursively print subdirectory
            print_tree_dirs_only(item_path, extension, is_last_item, max_depth, current_depth + 1, show_files_at_root=False)
        else:
            print(current_prefix + item)

# Print the BIDS directory structure (directories only in nested folders)
print("\nBIDS Directory Structure (folders only in subfolders):")
print("=" * 50)
print_tree_dirs_only(layout.root)
# Out:
# BIDS Directory Structure (folders only in subfolders):
# ==================================================
# eeg_face13/
# ├── code/
# │   └── BIDS-Init-Face13-EEGLAB/
# ├── sourcedata/
# │   ├── eeg/
# │   ├── misc/
# │   └── tasks/
# │       └── Stim/
# ├── sub-001/
# │   └── eeg/
# ├── sub-002/
# │   └── eeg/
# ├── sub-003/
# │   └── eeg/
# ├── sub-004/
# │   └── eeg/
# ├── sub-005/
# │   └── eeg/
# ├── sub-006/
# │   └── eeg/
# ├── sub-007/
# │   └── eeg/
# ├── sub-008/
# │   └── eeg/
# ├── sub-009/
# │   └── eeg/
# ├── sub-010/
# │   └── eeg/
# ├── README
# ├── dataset_description.json
# └── participants.tsv

# %%
# AI generated code to print directory tree
def print_tree(directory, prefix="", is_last=True, max_depth=None, current_depth=0):
    """
    Print an ASCII tree structure of a directory
    """
    if max_depth is not None and current_depth >= max_depth:
        return
    
    # Get the directory name
    dir_name = os.path.basename(directory)
    
    # Print current directory
    if current_depth == 0:
        print(dir_name + "/")
    
    # Get all items in directory
    try:
        items = sorted(os.listdir(directory))
    except PermissionError:
        return
    
    # Filter out hidden files and .git directory
    items = [item for item in items if not item.startswith('.')]
    
    # Separate directories and files
    dirs = [item for item in items if os.path.isdir(os.path.join(directory, item))]
    files = [item for item in items if os.path.isfile(os.path.join(directory, item))]
    
    # Combine them (directories first, then files)
    all_items = dirs + files
    
    for i, item in enumerate(all_items):
        is_last_item = i == len(all_items) - 1
        item_path = os.path.join(directory, item)
        
        # Determine the prefix for this item
        if is_last_item:
            current_prefix = prefix + "└── "
            extension = prefix + "    "
        else:
            current_prefix = prefix + "├── "
            extension = prefix + "│   "
        
        # Print the item
        if os.path.isdir(item_path):
            print(current_prefix + item + "/")
            # Recursively print subdirectory
            print_tree(item_path, extension, is_last_item, max_depth, current_depth + 1)
        else:
            print(current_prefix + item)

# Print the BIDS directory structure
print("\nBIDS Directory Structure:")
print("=" * 50)
print_tree(layout.root)
# Out:
# BIDS Directory Structure:
# ==================================================
# eeg_face13/
# ├── code/
# │   └── BIDS-Init-Face13-EEGLAB/
# │       ├── README.md
# │       ├── bids_face13.m
# │       ├── bids_face13_min.m
# │       ├── eeg_init.m
# │       └── init_script.m
# ├── sourcedata/
# │   ├── eeg/
# │   │   ├── IC_trn_P01_F_1.bdf
# │   │   ├── IC_trn_P01_F_2.bdf
# │   │   ├── IC_trn_P01_O_1.bdf
# │   │   ├── IC_trn_P01_O_2.bdf
# │   │   ├── IC_trn_P01_O_3.bdf
# │   │   ├── IC_trn_P01_O_4.bdf
# │   │   ├── IC_trn_P01_f_3.bdf
# │   │   ├── IC_trn_P01_f_4.bdf
# │   │   ├── IC_trn_P02_F_1.bdf
# │   │   ├── IC_trn_P02_F_2.bdf
# │   │   ├── IC_trn_P02_F_3.bdf
# │   │   ├── IC_trn_P02_F_4.bdf
# │   │   ├── IC_trn_P02_O_1.bdf
# │   │   ├── IC_trn_P02_O_2.bdf
# │   │   ├── IC_trn_P02_O_3.bdf
# │   │   ├── IC_trn_P02_O_4.bdf
# │   │   ├── IC_trn_P03_F_1.bdf
# │   │   ├── IC_trn_P03_F_2.bdf
# │   │   ├── IC_trn_P03_F_3.bdf
# │   │   ├── IC_trn_P03_F_4.bdf
# │   │   ├── IC_trn_P03_O_1.bdf
# │   │   ├── IC_trn_P03_O_2.bdf
# │   │   ├── IC_trn_P03_O_3.bdf
# │   │   ├── IC_trn_P03_O_4.bdf
# │   │   ├── IC_trn_P04_F_1.bdf
# │   │   ├── IC_trn_P04_F_2.bdf
# │   │   ├── IC_trn_P04_F_3.bdf
# │   │   ├── IC_trn_P04_F_4.bdf
# │   │   ├── IC_trn_P04_O_1.bdf
# │   │   ├── IC_trn_P04_O_2.bdf
# │   │   ├── IC_trn_P04_O_3.bdf
# │   │   ├── IC_trn_P04_O_4.bdf
# │   │   ├── IC_trn_P05_F_1.bdf
# │   │   ├── IC_trn_P05_F_2.bdf
# │   │   ├── IC_trn_P05_F_3.bdf
# │   │   ├── IC_trn_P05_F_4.bdf
# │   │   ├── IC_trn_P05_O_1.bdf
# │   │   ├── IC_trn_P05_O_2.bdf
# │   │   ├── IC_trn_P05_O_3.bdf
# │   │   ├── IC_trn_P05_O_4.bdf
# │   │   ├── IC_trn_P06_F_1.bdf
# │   │   ├── IC_trn_P06_F_2.bdf
# │   │   ├── IC_trn_P06_F_3.bdf
# │   │   ├── IC_trn_P06_F_4.bdf
# │   │   ├── IC_trn_P06_O_1.bdf
# │   │   ├── IC_trn_P06_O_2.bdf
# │   │   ├── IC_trn_P06_O_3.bdf
# │   │   ├── IC_trn_P06_O_4.bdf
# │   │   ├── IC_trn_P07_F_1.bdf
# │   │   ├── IC_trn_P07_F_2.bdf
# │   │   ├── IC_trn_P07_F_3.bdf
# │   │   ├── IC_trn_P07_F_4.bdf
# │   │   ├── IC_trn_P07_O_1.bdf
# │   │   ├── IC_trn_P07_O_2.bdf
# │   │   ├── IC_trn_P07_O_3.bdf
# │   │   ├── IC_trn_P07_O_4.bdf
# │   │   ├── IC_trn_P08_F_1.bdf
# │   │   ├── IC_trn_P08_F_2.bdf
# │   │   ├── IC_trn_P08_F_3.bdf
# │   │   ├── IC_trn_P08_F_4.bdf
# │   │   ├── IC_trn_P08_O_1.bdf
# │   │   ├── IC_trn_P08_O_2.bdf
# │   │   ├── IC_trn_P08_O_3.bdf
# │   │   ├── IC_trn_P08_O_4.bdf
# │   │   ├── IC_trn_P09_F_1.bdf
# │   │   ├── IC_trn_P09_F_2.bdf
# │   │   ├── IC_trn_P09_F_3.bdf
# │   │   ├── IC_trn_P09_F_4.bdf
# │   │   ├── IC_trn_P09_O_1.bdf
# │   │   ├── IC_trn_P09_O_2.bdf
# │   │   ├── IC_trn_P09_O_3.bdf
# │   │   ├── IC_trn_P09_O_4.bdf
# │   │   ├── IC_trn_P10_F_1.bdf
# │   │   ├── IC_trn_P10_F_2.bdf
# │   │   ├── IC_trn_P10_F_3.bdf
# │   │   ├── IC_trn_P10_F_4.bdf
# │   │   ├── IC_trn_P10_O_1.bdf
# │   │   ├── IC_trn_P10_O_2.bdf
# │   │   ├── IC_trn_P10_O_3.bdf
# │   │   ├── IC_trn_P10_O_4.bdf
# │   │   ├── RawData_NameChange_log.txt
# │   │   ├── sub-s01.log
# │   │   ├── sub-s01_task-faceFO_eeg.fdt
# │   │   ├── sub-s01_task-faceFO_eeg.set
# │   │   ├── sub-s02.log
# │   │   ├── sub-s02_task-faceFO_eeg.fdt
# │   │   ├── sub-s02_task-faceFO_eeg.set
# │   │   ├── sub-s03.log
# │   │   ├── sub-s03_task-faceFO_eeg.fdt
# │   │   ├── sub-s03_task-faceFO_eeg.set
# │   │   ├── sub-s04.log
# │   │   ├── sub-s04_task-faceFO_eeg.fdt
# │   │   ├── sub-s04_task-faceFO_eeg.set
# │   │   ├── sub-s05.log
# │   │   ├── sub-s05_task-faceFO_eeg.fdt
# │   │   ├── sub-s05_task-faceFO_eeg.set
# │   │   ├── sub-s06.log
# │   │   ├── sub-s06_task-faceFO_eeg.fdt
# │   │   ├── sub-s06_task-faceFO_eeg.set
# │   │   ├── sub-s07.log
# │   │   ├── sub-s07_task-faceFO_eeg.fdt
# │   │   ├── sub-s07_task-faceFO_eeg.set
# │   │   ├── sub-s08.log
# │   │   ├── sub-s08_task-faceFO_eeg.fdt
# │   │   ├── sub-s08_task-faceFO_eeg.set
# │   │   ├── sub-s09.log
# │   │   ├── sub-s09_task-faceFO_eeg.fdt
# │   │   ├── sub-s09_task-faceFO_eeg.set
# │   │   ├── sub-s10.log
# │   │   ├── sub-s10_task-faceFO_eeg.fdt
# │   │   └── sub-s10_task-faceFO_eeg.set
# │   ├── misc/
# │   │   ├── BioSemi_BUCANL_EEGLAB.sfp
# │   │   ├── standard_1005.elc
# │   │   └── standard_vol_SCCN.mat
# │   └── tasks/
# │       ├── Stim/
# │       │   ├── Black.bmp
# │       │   ├── C1.bmp
# │       │   ├── C1O1_F0.bmp
# │       │   ├── C1O1_F0_L.bmp
# │       │   ├── C1O1_F0_R.bmp
# │       │   ├── C1O1_F1.bmp
# │       │   ├── C1O1_F2.bmp
# │       │   ├── C1O1_F3.bmp
# │       │   ├── C1O1_F4.bmp
# │       │   ├── C1O1_F5.bmp
# │       │   ├── C1O1_F6.bmp
# │       │   ├── C1O1_F7.bmp
# │       │   ├── C1O1_F8.bmp
# │       │   ├── C1O2_F0.bmp
# │       │   ├── C1O2_F1.bmp
# │       │   ├── C1O2_F2.bmp
# │       │   ├── C1O2_F3.bmp
# │       │   ├── C1O2_F4.bmp
# │       │   ├── C1O2_F5.bmp
# │       │   ├── C1O2_F6.bmp
# │       │   ├── C1O2_F7.bmp
# │       │   ├── C1O2_F8.bmp
# │       │   ├── F1A.bmp
# │       │   ├── F1AO1_F0.bmp
# │       │   ├── F1AO1_F1.bmp
# │       │   ├── F1AO1_F10.bmp
# │       │   ├── F1AO1_F2.bmp
# │       │   ├── F1AO1_F3.bmp
# │       │   ├── F1AO1_F4.bmp
# │       │   ├── F1AO1_F5.bmp
# │       │   ├── F1AO1_F6.bmp
# │       │   ├── F1AO1_F7.bmp
# │       │   ├── F1AO1_F8.bmp
# │       │   ├── F1AO1_F9.bmp
# │       │   ├── F1AO1_SF_L10.bmp
# │       │   ├── F1AO2_F0.bmp
# │       │   ├── F1AO2_F1.bmp
# │       │   ├── F1AO2_F10.bmp
# │       │   ├── F1AO2_F2.bmp
# │       │   ├── F1AO2_F3.bmp
# │       │   ├── F1AO2_F4.bmp
# │       │   ├── F1AO2_F5.bmp
# │       │   ├── F1AO2_F6.bmp
# │       │   ├── F1AO2_F7.bmp
# │       │   ├── F1AO2_F8.bmp
# │       │   ├── F1AO2_F9.bmp
# │       │   ├── F1AO2_SF_L10.bmp
# │       │   ├── F1F.bmp
# │       │   ├── F1FO1_F0.bmp
# │       │   ├── F1FO1_F1.bmp
# │       │   ├── F1FO1_F10.bmp
# │       │   ├── F1FO1_F2.bmp
# │       │   ├── F1FO1_F3.bmp
# │       │   ├── F1FO1_F4.bmp
# │       │   ├── F1FO1_F5.bmp
# │       │   ├── F1FO1_F6.bmp
# │       │   ├── F1FO1_F7.bmp
# │       │   ├── F1FO1_F8.bmp
# │       │   ├── F1FO1_F9.bmp
# │       │   ├── F1FO1_SF_L10.bmp
# │       │   ├── F1FO2_F0.bmp
# │       │   ├── F1FO2_F1.bmp
# │       │   ├── F1FO2_F10.bmp
# │       │   ├── F1FO2_F2.bmp
# │       │   ├── F1FO2_F3.bmp
# │       │   ├── F1FO2_F4.bmp
# │       │   ├── F1FO2_F5.bmp
# │       │   ├── F1FO2_F6.bmp
# │       │   ├── F1FO2_F7.bmp
# │       │   ├── F1FO2_F8.bmp
# │       │   ├── F1FO2_F9.bmp
# │       │   ├── F1FO2_SF_L10.bmp
# │       │   ├── F2A.bmp
# │       │   ├── F2AO1_F0.bmp
# │       │   ├── F2AO1_F1.bmp
# │       │   ├── F2AO1_F10.bmp
# │       │   ├── F2AO1_F2.bmp
# │       │   ├── F2AO1_F3.bmp
# │       │   ├── F2AO1_F4.bmp
# │       │   ├── F2AO1_F5.bmp
# │       │   ├── F2AO1_F6.bmp
# │       │   ├── F2AO1_F7.bmp
# │       │   ├── F2AO1_F8.bmp
# │       │   ├── F2AO1_F9.bmp
# │       │   ├── F2AO1_SF_L10.bmp
# │       │   ├── F2AO2_F0.bmp
# │       │   ├── F2AO2_F1.bmp
# │       │   ├── F2AO2_F10.bmp
# │       │   ├── F2AO2_F2.bmp
# │       │   ├── F2AO2_F3.bmp
# │       │   ├── F2AO2_F4.bmp
# │       │   ├── F2AO2_F5.bmp
# │       │   ├── F2AO2_F6.bmp
# │       │   ├── F2AO2_F7.bmp
# │       │   ├── F2AO2_F8.bmp
# │       │   ├── F2AO2_F9.bmp
# │       │   ├── F2AO2_SF_L10.bmp
# │       │   ├── F2F.bmp
# │       │   ├── F2FO1_F0.bmp
# │       │   ├── F2FO1_F1.bmp
# │       │   ├── F2FO1_F10.bmp
# │       │   ├── F2FO1_F2.bmp
# │       │   ├── F2FO1_F3.bmp
# │       │   ├── F2FO1_F4.bmp
# │       │   ├── F2FO1_F5.bmp
# │       │   ├── F2FO1_F6.bmp
# │       │   ├── F2FO1_F7.bmp
# │       │   ├── F2FO1_F8.bmp
# │       │   ├── F2FO1_F9.bmp
# │       │   ├── F2FO1_SF_L10.bmp
# │       │   ├── F2FO2_F0.bmp
# │       │   ├── F2FO2_F1.bmp
# │       │   ├── F2FO2_F10.bmp
# │       │   ├── F2FO2_F2.bmp
# │       │   ├── F2FO2_F3.bmp
# │       │   ├── F2FO2_F4.bmp
# │       │   ├── F2FO2_F5.bmp
# │       │   ├── F2FO2_F6.bmp
# │       │   ├── F2FO2_F7.bmp
# │       │   ├── F2FO2_F8.bmp
# │       │   ├── F2FO2_F9.bmp
# │       │   ├── F2FO2_SF_L10.bmp
# │       │   ├── F3A.bmp
# │       │   ├── F3AO1_F0.bmp
# │       │   ├── F3AO1_F1.bmp
# │       │   ├── F3AO1_F10.bmp
# │       │   ├── F3AO1_F2.bmp
# │       │   ├── F3AO1_F3.bmp
# │       │   ├── F3AO1_F4.bmp
# │       │   ├── F3AO1_F5.bmp
# │       │   ├── F3AO1_F6.bmp
# │       │   ├── F3AO1_F7.bmp
# │       │   ├── F3AO1_F8.bmp
# │       │   ├── F3AO1_F9.bmp
# │       │   ├── F3AO1_SF_L10.bmp
# │       │   ├── F3AO2_F0.bmp
# │       │   ├── F3AO2_F1.bmp
# │       │   ├── F3AO2_F10.bmp
# │       │   ├── F3AO2_F2.bmp
# │       │   ├── F3AO2_F3.bmp
# │       │   ├── F3AO2_F4.bmp
# │       │   ├── F3AO2_F5.bmp
# │       │   ├── F3AO2_F6.bmp
# │       │   ├── F3AO2_F7.bmp
# │       │   ├── F3AO2_F8.bmp
# │       │   ├── F3AO2_F9.bmp
# │       │   ├── F3AO2_SF_L10.bmp
# │       │   ├── F3F.bmp
# │       │   ├── F3FO1_F0.bmp
# │       │   ├── F3FO1_F1.bmp
# │       │   ├── F3FO1_F10.bmp
# │       │   ├── F3FO1_F2.bmp
# │       │   ├── F3FO1_F3.bmp
# │       │   ├── F3FO1_F4.bmp
# │       │   ├── F3FO1_F5.bmp
# │       │   ├── F3FO1_F6.bmp
# │       │   ├── F3FO1_F7.bmp
# │       │   ├── F3FO1_F8.bmp
# │       │   ├── F3FO1_F9.bmp
# │       │   ├── F3FO1_SF_L10.bmp
# │       │   ├── F3FO2_F0.bmp
# │       │   ├── F3FO2_F1.bmp
# │       │   ├── F3FO2_F10.bmp
# │       │   ├── F3FO2_F2.bmp
# │       │   ├── F3FO2_F3.bmp
# │       │   ├── F3FO2_F4.bmp
# │       │   ├── F3FO2_F5.bmp
# │       │   ├── F3FO2_F6.bmp
# │       │   ├── F3FO2_F7.bmp
# │       │   ├── F3FO2_F8.bmp
# │       │   ├── F3FO2_F9.bmp
# │       │   ├── F3FO2_SF_L10.bmp
# │       │   ├── F4A.bmp
# │       │   ├── F4AO1_F0.bmp
# │       │   ├── F4AO1_F1.bmp
# │       │   ├── F4AO1_F10.bmp
# │       │   ├── F4AO1_F2.bmp
# │       │   ├── F4AO1_F3.bmp
# │       │   ├── F4AO1_F4.bmp
# │       │   ├── F4AO1_F5.bmp
# │       │   ├── F4AO1_F6.bmp
# │       │   ├── F4AO1_F7.bmp
# │       │   ├── F4AO1_F8.bmp
# │       │   ├── F4AO1_F9.bmp
# │       │   ├── F4AO1_SF_L10.bmp
# │       │   ├── F4AO2_F0.bmp
# │       │   ├── F4AO2_F1.bmp
# │       │   ├── F4AO2_F10.bmp
# │       │   ├── F4AO2_F2.bmp
# │       │   ├── F4AO2_F3.bmp
# │       │   ├── F4AO2_F4.bmp
# │       │   ├── F4AO2_F5.bmp
# │       │   ├── F4AO2_F6.bmp
# │       │   ├── F4AO2_F7.bmp
# │       │   ├── F4AO2_F8.bmp
# │       │   ├── F4AO2_F9.bmp
# │       │   ├── F4AO2_SF_L10.bmp
# │       │   ├── F4F.bmp
# │       │   ├── F4FO1_F0.bmp
# │       │   ├── F4FO1_F1.bmp
# │       │   ├── F4FO1_F10.bmp
# │       │   ├── F4FO1_F2.bmp
# │       │   ├── F4FO1_F3.bmp
# │       │   ├── F4FO1_F4.bmp
# │       │   ├── F4FO1_F5.bmp
# │       │   ├── F4FO1_F6.bmp
# │       │   ├── F4FO1_F7.bmp
# │       │   ├── F4FO1_F8.bmp
# │       │   ├── F4FO1_F9.bmp
# │       │   ├── F4FO1_SF_L10.bmp
# │       │   ├── F4FO2_F0.bmp
# │       │   ├── F4FO2_F1.bmp
# │       │   ├── F4FO2_F10.bmp
# │       │   ├── F4FO2_F2.bmp
# │       │   ├── F4FO2_F3.bmp
# │       │   ├── F4FO2_F4.bmp
# │       │   ├── F4FO2_F5.bmp
# │       │   ├── F4FO2_F6.bmp
# │       │   ├── F4FO2_F7.bmp
# │       │   ├── F4FO2_F8.bmp
# │       │   ├── F4FO2_F9.bmp
# │       │   ├── F4FO2_SF_L10.bmp
# │       │   ├── F5A.bmp
# │       │   ├── F5AO1_F0.bmp
# │       │   ├── F5AO1_F1.bmp
# │       │   ├── F5AO1_F10.bmp
# │       │   ├── F5AO1_F2.bmp
# │       │   ├── F5AO1_F3.bmp
# │       │   ├── F5AO1_F4.bmp
# │       │   ├── F5AO1_F5.bmp
# │       │   ├── F5AO1_F6.bmp
# │       │   ├── F5AO1_F7.bmp
# │       │   ├── F5AO1_F8.bmp
# │       │   ├── F5AO1_F9.bmp
# │       │   ├── F5AO1_SF_L10.bmp
# │       │   ├── F5AO2_F0.bmp
# │       │   ├── F5AO2_F1.bmp
# │       │   ├── F5AO2_F10.bmp
# │       │   ├── F5AO2_F2.bmp
# │       │   ├── F5AO2_F3.bmp
# │       │   ├── F5AO2_F4.bmp
# │       │   ├── F5AO2_F5.bmp
# │       │   ├── F5AO2_F6.bmp
# │       │   ├── F5AO2_F7.bmp
# │       │   ├── F5AO2_F8.bmp
# │       │   ├── F5AO2_F9.bmp
# │       │   ├── F5AO2_SF_L10.bmp
# │       │   ├── F5F.bmp
# │       │   ├── F5FO1_F0.bmp
# │       │   ├── F5FO1_F1.bmp
# │       │   ├── F5FO1_F10.bmp
# │       │   ├── F5FO1_F2.bmp
# │       │   ├── F5FO1_F3.bmp
# │       │   ├── F5FO1_F4.bmp
# │       │   ├── F5FO1_F5.bmp
# │       │   ├── F5FO1_F6.bmp
# │       │   ├── F5FO1_F7.bmp
# │       │   ├── F5FO1_F8.bmp
# │       │   ├── F5FO1_F9.bmp
# │       │   ├── F5FO1_SF_L10.bmp
# │       │   ├── F5FO2_F0.bmp
# │       │   ├── F5FO2_F1.bmp
# │       │   ├── F5FO2_F10.bmp
# │       │   ├── F5FO2_F2.bmp
# │       │   ├── F5FO2_F3.bmp
# │       │   ├── F5FO2_F4.bmp
# │       │   ├── F5FO2_F5.bmp
# │       │   ├── F5FO2_F6.bmp
# │       │   ├── F5FO2_F7.bmp
# │       │   ├── F5FO2_F8.bmp
# │       │   ├── F5FO2_F9.bmp
# │       │   ├── F5FO2_SF_L10.bmp
# │       │   ├── F6AO1_F0.bmp
# │       │   ├── F6AO1_F1.bmp
# │       │   ├── F6AO1_F10.bmp
# │       │   ├── F6AO1_F2.bmp
# │       │   ├── F6AO1_F3.bmp
# │       │   ├── F6AO1_F4.bmp
# │       │   ├── F6AO1_F5.bmp
# │       │   ├── F6AO1_F6.bmp
# │       │   ├── F6AO1_F7.bmp
# │       │   ├── F6AO1_F8.bmp
# │       │   ├── F6AO1_F9.bmp
# │       │   ├── F6AO1_SF_L10.bmp
# │       │   ├── F6AO2_F0.bmp
# │       │   ├── F6AO2_F1.bmp
# │       │   ├── F6AO2_F10.bmp
# │       │   ├── F6AO2_F2.bmp
# │       │   ├── F6AO2_F3.bmp
# │       │   ├── F6AO2_F4.bmp
# │       │   ├── F6AO2_F5.bmp
# │       │   ├── F6AO2_F6.bmp
# │       │   ├── F6AO2_F7.bmp
# │       │   ├── F6AO2_F8.bmp
# │       │   ├── F6AO2_F9.bmp
# │       │   ├── F6FO1_F0.bmp
# │       │   ├── F6FO1_F1.bmp
# │       │   ├── F6FO1_F10.bmp
# │       │   ├── F6FO1_F2.bmp
# │       │   ├── F6FO1_F3.bmp
# │       │   ├── F6FO1_F4.bmp
# │       │   ├── F6FO1_F5.bmp
# │       │   ├── F6FO1_F6.bmp
# │       │   ├── F6FO1_F7.bmp
# │       │   ├── F6FO1_F8.bmp
# │       │   ├── F6FO1_F9.bmp
# │       │   ├── F6FO1_SF_L10.bmp
# │       │   ├── F6FO2_F0.bmp
# │       │   ├── F6FO2_F1.bmp
# │       │   ├── F6FO2_F10.bmp
# │       │   ├── F6FO2_F2.bmp
# │       │   ├── F6FO2_F3.bmp
# │       │   ├── F6FO2_F4.bmp
# │       │   ├── F6FO2_F5.bmp
# │       │   ├── F6FO2_F6.bmp
# │       │   ├── F6FO2_F7.bmp
# │       │   ├── F6FO2_F8.bmp
# │       │   ├── F6FO2_F9.bmp
# │       │   ├── FaceMod.asv
# │       │   ├── FaceMod.m
# │       │   ├── H1.bmp
# │       │   ├── H1O1_F0.bmp
# │       │   ├── H1O1_F1.bmp
# │       │   ├── H1O1_F10.bmp
# │       │   ├── H1O1_F2.bmp
# │       │   ├── H1O1_F3.bmp
# │       │   ├── H1O1_F4.bmp
# │       │   ├── H1O1_F5.bmp
# │       │   ├── H1O1_F6.bmp
# │       │   ├── H1O1_F7.bmp
# │       │   ├── H1O1_F8.bmp
# │       │   ├── H1O1_F9.bmp
# │       │   ├── H1O2_F0.bmp
# │       │   ├── H1O2_F1.bmp
# │       │   ├── H1O2_F10.bmp
# │       │   ├── H1O2_F2.bmp
# │       │   ├── H1O2_F3.bmp
# │       │   ├── H1O2_F4.bmp
# │       │   ├── H1O2_F5.bmp
# │       │   ├── H1O2_F6.bmp
# │       │   ├── H1O2_F7.bmp
# │       │   ├── H1O2_F8.bmp
# │       │   ├── H1O2_F9.bmp
# │       │   ├── H2.bmp
# │       │   ├── H2O1_F0.bmp
# │       │   ├── H2O1_F1.bmp
# │       │   ├── H2O1_F10.bmp
# │       │   ├── H2O1_F2.bmp
# │       │   ├── H2O1_F3.bmp
# │       │   ├── H2O1_F4.bmp
# │       │   ├── H2O1_F5.bmp
# │       │   ├── H2O1_F6.bmp
# │       │   ├── H2O1_F7.bmp
# │       │   ├── H2O1_F8.bmp
# │       │   ├── H2O1_F9.bmp
# │       │   ├── H2O2_F0.bmp
# │       │   ├── H2O2_F1.bmp
# │       │   ├── H2O2_F10.bmp
# │       │   ├── H2O2_F2.bmp
# │       │   ├── H2O2_F3.bmp
# │       │   ├── H2O2_F4.bmp
# │       │   ├── H2O2_F5.bmp
# │       │   ├── H2O2_F6.bmp
# │       │   ├── H2O2_F7.bmp
# │       │   ├── H2O2_F8.bmp
# │       │   ├── H2O2_F9.bmp
# │       │   ├── H3.bmp
# │       │   ├── H3O1_F0.bmp
# │       │   ├── H3O1_F1.bmp
# │       │   ├── H3O1_F10.bmp
# │       │   ├── H3O1_F2.bmp
# │       │   ├── H3O1_F3.bmp
# │       │   ├── H3O1_F4.bmp
# │       │   ├── H3O1_F5.bmp
# │       │   ├── H3O1_F6.bmp
# │       │   ├── H3O1_F7.bmp
# │       │   ├── H3O1_F8.bmp
# │       │   ├── H3O1_F9.bmp
# │       │   ├── H3O2_F0.bmp
# │       │   ├── H3O2_F1.bmp
# │       │   ├── H3O2_F10.bmp
# │       │   ├── H3O2_F2.bmp
# │       │   ├── H3O2_F3.bmp
# │       │   ├── H3O2_F4.bmp
# │       │   ├── H3O2_F5.bmp
# │       │   ├── H3O2_F6.bmp
# │       │   ├── H3O2_F7.bmp
# │       │   ├── H3O2_F8.bmp
# │       │   ├── H3O2_F9.bmp
# │       │   ├── H4.bmp
# │       │   ├── H4O1_F0.bmp
# │       │   ├── H4O1_F1.bmp
# │       │   ├── H4O1_F10.bmp
# │       │   ├── H4O1_F2.bmp
# │       │   ├── H4O1_F3.bmp
# │       │   ├── H4O1_F4.bmp
# │       │   ├── H4O1_F5.bmp
# │       │   ├── H4O1_F6.bmp
# │       │   ├── H4O1_F7.bmp
# │       │   ├── H4O1_F8.bmp
# │       │   ├── H4O1_F9.bmp
# │       │   ├── H4O2_F0.bmp
# │       │   ├── H4O2_F1.bmp
# │       │   ├── H4O2_F10.bmp
# │       │   ├── H4O2_F2.bmp
# │       │   ├── H4O2_F3.bmp
# │       │   ├── H4O2_F4.bmp
# │       │   ├── H4O2_F5.bmp
# │       │   ├── H4O2_F6.bmp
# │       │   ├── H4O2_F7.bmp
# │       │   ├── H4O2_F8.bmp
# │       │   ├── H4O2_F9.bmp
# │       │   ├── H5.bmp
# │       │   ├── H5O1_F0.bmp
# │       │   ├── H5O1_F1.bmp
# │       │   ├── H5O1_F10.bmp
# │       │   ├── H5O1_F2.bmp
# │       │   ├── H5O1_F3.bmp
# │       │   ├── H5O1_F4.bmp
# │       │   ├── H5O1_F5.bmp
# │       │   ├── H5O1_F6.bmp
# │       │   ├── H5O1_F7.bmp
# │       │   ├── H5O1_F8.bmp
# │       │   ├── H5O1_F9.bmp
# │       │   ├── H5O2_F0.bmp
# │       │   ├── H5O2_F1.bmp
# │       │   ├── H5O2_F10.bmp
# │       │   ├── H5O2_F2.bmp
# │       │   ├── H5O2_F3.bmp
# │       │   ├── H5O2_F4.bmp
# │       │   ├── H5O2_F5.bmp
# │       │   ├── H5O2_F6.bmp
# │       │   ├── H5O2_F7.bmp
# │       │   ├── H5O2_F8.bmp
# │       │   ├── H5O2_F9.bmp
# │       │   ├── MaskBMP.asv
# │       │   ├── MaskBMP.m
# │       │   ├── MaskF.bmp
# │       │   ├── MaskFi.bmp
# │       │   └── Thumbs.db
# │       ├── ICTrn_FHC_Onset_LR_300Blk.ebs
# │       ├── ICTrn_FHC_Onset_LR_300Blk.es
# │       ├── ICTrn_FHC_SpFq_250Blk.ebs
# │       └── ICTrn_FHC_SpFq_250Blk.es
# ├── sub-001/
# │   └── eeg/
# │       ├── sub-001_coordsystem.json
# │       ├── sub-001_electrodes.tsv
# │       ├── sub-001_task-faceFO_channels.tsv
# │       ├── sub-001_task-faceFO_eeg.edf
# │       ├── sub-001_task-faceFO_eeg.json
# │       └── sub-001_task-faceFO_events.tsv
# ├── sub-002/
# │   └── eeg/
# │       ├── sub-002_coordsystem.json
# │       ├── sub-002_electrodes.tsv
# │       ├── sub-002_task-faceFO_channels.tsv
# │       ├── sub-002_task-faceFO_eeg.edf
# │       ├── sub-002_task-faceFO_eeg.json
# │       └── sub-002_task-faceFO_events.tsv
# ├── sub-003/
# │   └── eeg/
# │       ├── sub-003_coordsystem.json
# │       ├── sub-003_electrodes.tsv
# │       ├── sub-003_task-faceFO_channels.tsv
# │       ├── sub-003_task-faceFO_eeg.edf
# │       ├── sub-003_task-faceFO_eeg.json
# │       └── sub-003_task-faceFO_events.tsv
# ├── sub-004/
# │   └── eeg/
# │       ├── sub-004_coordsystem.json
# │       ├── sub-004_electrodes.tsv
# │       ├── sub-004_task-faceFO_channels.tsv
# │       ├── sub-004_task-faceFO_eeg.edf
# │       ├── sub-004_task-faceFO_eeg.json
# │       └── sub-004_task-faceFO_events.tsv
# ├── sub-005/
# │   └── eeg/
# │       ├── sub-005_coordsystem.json
# │       ├── sub-005_electrodes.tsv
# │       ├── sub-005_task-faceFO_channels.tsv
# │       ├── sub-005_task-faceFO_eeg.edf
# │       ├── sub-005_task-faceFO_eeg.json
# │       └── sub-005_task-faceFO_events.tsv
# ├── sub-006/
# │   └── eeg/
# │       ├── sub-006_coordsystem.json
# │       ├── sub-006_electrodes.tsv
# │       ├── sub-006_task-faceFO_channels.tsv
# │       ├── sub-006_task-faceFO_eeg.edf
# │       ├── sub-006_task-faceFO_eeg.json
# │       └── sub-006_task-faceFO_events.tsv
# ├── sub-007/
# │   └── eeg/
# │       ├── sub-007_coordsystem.json
# │       ├── sub-007_electrodes.tsv
# │       ├── sub-007_task-faceFO_channels.tsv
# │       ├── sub-007_task-faceFO_eeg.edf
# │       ├── sub-007_task-faceFO_eeg.json
# │       └── sub-007_task-faceFO_events.tsv
# ├── sub-008/
# │   └── eeg/
# │       ├── sub-008_coordsystem.json
# │       ├── sub-008_electrodes.tsv
# │       ├── sub-008_task-faceFO_channels.tsv
# │       ├── sub-008_task-faceFO_eeg.edf
# │       ├── sub-008_task-faceFO_eeg.json
# │       └── sub-008_task-faceFO_events.tsv
# ├── sub-009/
# │   └── eeg/
# │       ├── sub-009_coordsystem.json
# │       ├── sub-009_electrodes.tsv
# │       ├── sub-009_task-faceFO_channels.tsv
# │       ├── sub-009_task-faceFO_eeg.edf
# │       ├── sub-009_task-faceFO_eeg.json
# │       └── sub-009_task-faceFO_events.tsv
# ├── sub-010/
# │   └── eeg/
# │       ├── sub-010_coordsystem.json
# │       ├── sub-010_electrodes.tsv
# │       ├── sub-010_task-faceFO_channels.tsv
# │       ├── sub-010_task-faceFO_eeg.edf
# │       ├── sub-010_task-faceFO_eeg.json
# │       └── sub-010_task-faceFO_events.tsv
# ├── README
# ├── dataset_description.json
# └── participants.tsv
